# %%
import os
import numpy as np 
import pandas as pd

# %%
os.listdir('../../tianchi/kdd2020_rec/')
# Out:
# ['underexpose_test', 'underexpose_train']

# %%
os.listdir('../../tianchi/kdd2020_rec/underexpose_train/')
# Out:
# ['.DS_Store',
#  'underexpose_item_feat.csv',
#  'underexpose_train_click-0.csv',
#  'underexpose_train_click-1.csv',
#  'underexpose_train_click-2.csv',
#  'underexpose_train_click-3.csv',
#  'underexpose_train_click-4.csv',
#  'underexpose_train_click-5.csv',
#  'underexpose_train_click-6.csv',
#  'underexpose_train_click-7.csv',
#  'underexpose_train_click-8.csv',
#  'underexpose_train_click-9.csv',
#  'underexpose_user_feat.csv']

# %%
os.listdir('../../tianchi/kdd2020_rec/underexpose_test/')
# Out:
# ['.DS_Store',
#  'underexpose_test_click-0',
#  'underexpose_test_click-1',
#  'underexpose_test_click-2',
#  'underexpose_test_click-3',
#  'underexpose_test_click-4',
#  'underexpose_test_click-5',
#  'underexpose_test_click-6',
#  'underexpose_test_click-7',
#  'underexpose_test_click-8',
#  'underexpose_test_click-9']

# %%
os.listdir('../../tianchi/kdd2020_rec/underexpose_test/underexpose_test_click-0/')
# Out:
# ['underexpose_test_click-0.csv', 'underexpose_test_qtime-0.csv']

# %%
    now_phase = 2  
    train_path = '../../tianchi/kdd2020_rec/underexpose_train/'  
    test_path = '../../tianchi/kdd2020_rec/underexpose_test/'  
    recom_item = []  
  
    whole_click = pd.DataFrame()  
    for c in range(now_phase + 1):  
        print('phase:', c)  
        click_train = pd.read_csv(train_path + '/underexpose_train_click-{}.csv'.format(c), header=None,  names=['user_id', 'item_id', 'time'])  
        click_test = pd.read_csv(test_path + '/underexpose_test_click-{}//underexpose_test_click-{}.csv'.format(c,c), header=None,  names=['user_id', 'item_id', 'time'])  
  
        all_click = click_train.append(click_test)  
        whole_click = whole_click.append(all_click)
# Out:
# phase: 0
# phase: 1
# phase: 2

# %%
all_click
# Out:
#        user_id  item_id      time
# 0         4965       18  0.983991
# 1        12836       18  0.984007
# 2        21919       80  0.983994
# 3        10370      131  0.984063
# 4        28229      146  0.984010
# 5        18689      161  0.983932
# 6        25792      161  0.984057
# 7        21412      174  0.983941
# 8         2833      194  0.984059
# 9        32377      210  0.983948
# 10         956      215  0.983905
# 11       10625      225  0.983925
# 12        4043      253  0.983954
# 13       14329      264  0.983939
# 14       12071      312  0.984063
# 15       31234      312  0.983996
# 16       27713      392  0.984014
# 17       19526      396  0.984054
# 18        6631      412  0.983906
# 19       34816      416  0.983948
# 20       14708      416  0.984063
# 21       13322      448  0.983953
# 22       28333      448  0.984064
# 23       11019      472  0.983883
# 24       20017      472  0.983880
# 25       33503      472  0.984003
# ...
